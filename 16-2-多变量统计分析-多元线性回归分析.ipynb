# %%
import pandas as pd

# 加载数据
file_path = R'data\多元回归分析演示数据.xlsx'
数据表 = pd.read_excel(file_path)

# 显示数据的前几行以进行初步检查
数据表.head()
# Out:
#    福利措施  同侪关系  适应学习  创新学习  知识获取  知识流通  知识创新  财务控管  顾客认同  内部运作  学习成长  组织效能
# 0     7     8     7     5     9     8     6     5     5     5     5    20
# 1    11    10    17    13    15     7     4     5     5     5     5    20
# 2     9    10     7     8    20    16    13     6    10     6     5    27
# 3    12    14    14     9    19    14     4     5    12     7     5    29
# 4    12    13     7    13    22    18    14     5     5    10     9    29

# %%
import statsmodels.api as sm
# 使用指定的五个变量作为自变量进行多元线性回归分析
specified_variables = ['知识获取', '内部运作', '适应学习', '学习成长', '知识创新','福利措施','财务控管','知识流通']
X_specified = 数据表[specified_variables]
y = 数据表['组织效能']  # 因变量

# 多元线性回归
X_specified_with_constant = sm.add_constant(X_specified)  
model_specified = sm.OLS(y, X_specified_with_constant).fit()

# 显示回归结果
model_specified_summary = model_specified.summary()
model_specified_summary
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   组织效能   R-squared:                       0.981
# Model:                            OLS   Adj. R-squared:                  0.981
# Method:                 Least Squares   F-statistic:                     7615.
# Date:                Thu, 14 Dec 2023   Prob (F-statistic):               0.00
# Time:                        11:30:42   Log-Likelihood:                -2349.4
# No. Observations:                1200   AIC:                             4717.
# Df Residuals:                    1191   BIC:                             4763.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2458      0.319      3.902      0.000       0.619       1.872
# 知识获取           0.0126      0.016      0.775      0.439      -0.019       0.045
# 内部运作           1.4910      0.029     52.212      0.000       1.435       1.547
# 适应学习           0.0442      0.018      2.506      0.012       0.010       0.079
# 学习成长           1.1362      0.025     45.149      0.000       1.087       1.186
# 知识创新           0.0269      0.027      0.982      0.326      -0.027       0.081
# 福利措施           0.0541      0.027      2.027      0.043       0.002       0.106
# 财务控管           1.2331      0.020     60.286      0.000       1.193       1.273
# 知识流通          -0.0550      0.026     -2.140      0.033      -0.105      -0.005
# ==============================================================================
# Omnibus:                       67.724   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              176.341
# Skew:                           0.284   Prob(JB):                     5.11e-39
# Kurtosis:                       4.790   Cond. No.                         366.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """
