# %%
import pandas as pd

# %%
#读取上传的Excel文件
file_path_excel = R'data\国家认同数据清理后.xlsx'
df_excel = pd.read_excel(file_path_excel)
# 创建民族、年级和政治面貌的交互表
cross_tab = pd.crosstab(index=[df_excel['民族'], df_excel['年级']], 
                        columns=df_excel['政治面貌'], 
                        margins=True,normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 政治面貌           1         2         3         4       All
# 民族  年级
# 1   0   0.000000  0.000000  0.001284  0.000000  0.001284
#     1   0.119384  0.007702  0.010270  0.002567  0.139923
#     2   0.116816  0.019255  0.012837  0.002567  0.151476
#     3   0.039795  0.028241  0.007702  0.005135  0.080873
#     4   0.028241  0.014121  0.002567  0.000000  0.044929
# ...          ...       ...       ...       ...       ...
# 36  1   0.001284  0.000000  0.000000  0.000000  0.001284
# 47  2   0.001284  0.000000  0.000000  0.000000  0.001284
# 48  1   0.000000  0.001284  0.000000  0.000000  0.001284
# 97  2   0.001284  0.000000  0.000000  0.000000  0.001284
# All     0.736842  0.132221  0.110398  0.020539  1.000000
#
# [78 rows x 5 columns]

# %%
from scipy import stats
# 假设我们关注的是第二年级的学生（假设年级用数字“2”表示）
specific_grade = 2

# 筛选出特定年级的数据
df_specific_grade = df_excel[df_excel['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['会打多少分'], df_specific_grade['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
# chi2_grade, p_grade, dof_grade, expected_grade[:10]  # 展示期望频次的前10个结果，避免过长的输出
# Out:
# 20.269905911839633 0.06214943009111473

# %%
import pandas as pd
file_path_excel = R'data\国家认同数据清理后.xlsx'

# %%
df_excel = pd.read_excel(file_path_excel)
# 创建年级、政治面貌和会打多少分的交互表
cross_tab = pd.crosstab(index=[df_excel['政治面貌'], df_excel['会打多少分']], 
                        columns=df_excel['年级'], 
                        margins=True, normalize=True)  # All 行和列的总和

cross_tab
# Out:
# 年级                 0         1         2         3         4       All
# 政治面貌 会打多少分
# 1    1      0.000000  0.006418  0.011553  0.003851  0.000000  0.021823
#      2      0.000000  0.010270  0.012837  0.002567  0.001284  0.026958
#      3      0.005135  0.032092  0.043646  0.025674  0.010270  0.116816
#      4      0.008986  0.151476  0.110398  0.048780  0.037227  0.356868
#      5      0.001284  0.091142  0.066752  0.030809  0.024390  0.214377
# 2    1      0.000000  0.000000  0.001284  0.002567  0.002567  0.006418
#      2      0.000000  0.000000  0.001284  0.001284  0.000000  0.002567
#      3      0.000000  0.005135  0.011553  0.010270  0.005135  0.032092
#      4      0.000000  0.007702  0.007702  0.033376  0.007702  0.056483
#      5      0.000000  0.002567  0.012837  0.008986  0.010270  0.034660
# 3    1      0.000000  0.001284  0.000000  0.002567  0.000000  0.003851
#      2      0.000000  0.001284  0.001284  0.000000  0.001284  0.003851
#      3      0.000000  0.003851  0.016688  0.006418  0.005135  0.032092
#      4      0.000000  0.016688  0.010270  0.015404  0.005135  0.047497
#      5      0.001284  0.010270  0.005135  0.003851  0.002567  0.023107
# 4    3      0.000000  0.003851  0.001284  0.001284  0.000000  0.006418
#      4      0.000000  0.000000  0.003851  0.005135  0.000000  0.008986
#      5      0.000000  0.000000  0.001284  0.003851  0.000000  0.005135
# All         0.016688  0.344031  0.319641  0.206675  0.112965  1.000000

# %%
import pandas as pd
import mytools
from scipy import stats

# %%
认同数据表 = mytools.读取SPSS数据文件(R'data\国家认同数据清理后.sav')
cross_tab = pd.crosstab(index=[认同数据表['政治面貌'],认同数据表['会打多少分']],
                        columns=认同数据表['年级'],
                        margins=True,normalize=True)
cross_tab
# Out:
# 年级                预科        大一        大二        大三        大四       All
# 政治面貌 会打多少分
# 团员   零到二十   0.000000  0.006418  0.011553  0.003851  0.000000  0.021823
#      20~40  0.000000  0.010270  0.012837  0.002567  0.001284  0.026958
#      四十到六十  0.005135  0.032092  0.043646  0.025674  0.010270  0.116816
#      六十到八十  0.008986  0.151476  0.110398  0.048780  0.037227  0.356868
#      八十到一百  0.001284  0.091142  0.066752  0.030809  0.024390  0.214377
# 党员   零到二十   0.000000  0.000000  0.001284  0.002567  0.002567  0.006418
#      20~40  0.000000  0.000000  0.001284  0.001284  0.000000  0.002567
#      四十到六十  0.000000  0.005135  0.011553  0.010270  0.005135  0.032092
#      六十到八十  0.000000  0.007702  0.007702  0.033376  0.007702  0.056483
#      八十到一百  0.000000  0.002567  0.012837  0.008986  0.010270  0.034660
# 群众   零到二十   0.000000  0.001284  0.000000  0.002567  0.000000  0.003851
#      20~40  0.000000  0.001284  0.001284  0.000000  0.001284  0.003851
#      四十到六十  0.000000  0.003851  0.016688  0.006418  0.005135  0.032092
#      六十到八十  0.000000  0.016688  0.010270  0.015404  0.005135  0.047497
#      八十到一百  0.001284  0.010270  0.005135  0.003851  0.002567  0.023107
# 其他   四十到六十  0.000000  0.003851  0.001284  0.001284  0.000000  0.006418
#      六十到八十  0.000000  0.000000  0.003851  0.005135  0.000000  0.008986
#      八十到一百  0.000000  0.000000  0.001284  0.003851  0.000000  0.005135
# All         0.016688  0.344031  0.319641  0.206675  0.112965  1.000000

# %%
# 假设我们关注的是第一年级的学生（假设年级用数字“1”表示）
specific_grade ='大一'

# 筛选出特定年级的数据
df_specific_grade = 认同数据表[认同数据表['年级'] == specific_grade]

# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(df_specific_grade['会打多少分'], df_specific_grade['政治面貌'],
                                       margins=True, normalize=True)

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)

print(chi2_grade,p_grade)
cross_tab_specific_grade
# Out:
# 0.09847124851805246 1.0
# 政治面貌         团员        党员        群众        其他       All
# 会打多少分
# 零到二十   0.018657  0.000000  0.003731  0.000000  0.022388
# 20~40  0.029851  0.000000  0.003731  0.000000  0.033582
# 四十到六十  0.093284  0.014925  0.011194  0.011194  0.130597
# 六十到八十  0.440299  0.022388  0.048507  0.000000  0.511194
# 八十到一百  0.264925  0.007463  0.029851  0.000000  0.302239
# All    0.847015  0.044776  0.097015  0.011194  1.000000

# %%
# 创建政治面貌和会打多少分的交互表
cross_tab_specific_grade = pd.crosstab(认同数据表['会打多少分'], 认同数据表['政治面貌'])

# 进行卡方检验
chi2_grade, p_grade, dof_grade, expected_grade = stats.chi2_contingency(cross_tab_specific_grade)
print(chi2_grade, p_grade)
# Out:
# 16.22193387826521 0.1812812450681659

# %% [markdown]
# 因为P值约为0.181，小于0.5，所以接受虚无假设，所以大一年级“会打多少分”与“政治面貌”没有相关性
